# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import shutil
from math import ceil
from time import time
# %matplotlib inline

# %%
#os.environ["CUDA_VISIBLE_DEVICES"]="0"
tf.reset_default_graph()

# %%
def FindAgeRange(csvfile):
    df = pd.read_csv(csvfile)
    return (df['age'].min(), df['age'].max())

# %%
AGE_CSV = "sports_clean_age_list_extreme_biased.csv"
GEN_CSV = "gen_list_extreme_biased.csv"

# %%
# Model Parameters
IMG_SIZE      = [96, 96]
BATCH_SIZE    = 32
ITERS         = 10
EPOCHS        = 50
LEARNING_RATE = 0.001
SPLIT         = {"train" : 0.7, "validation": 0.1, "test": 0.2}

# For age classification
AGE_MIN, AGE_MAX = FindAgeRange(AGE_CSV)
BIN_SIZE         = 4
NUM_BINS         = (AGE_MAX-AGE_MIN)//BIN_SIZE
NUM_CLASSES_AGE  = NUM_BINS+1

# For gender classification
NUM_CLASSES_GEN = 2

# The weight of confusion loss
ALPHA = 2

# %%
def ReadImages(elem):
    filename = elem["name"][0]
    image_string = tf.read_file(filename)
    image_decoded = tf.image.decode_jpeg(image_string, channels=3)
    image = tf.cast(image_decoded, tf.uint8)
    image = tf.image.resize_images(image, IMG_SIZE)
    elem["name"] = image
    return elem

# %%
def AgeLabelFunc(elem):
    label = elem["age"][0]
    label = (label-AGE_MIN)//BIN_SIZE
    elem["age"] = label
    return elem

# %%
def GenderLabelFunc(elem):
    elem["gender"] = elem["gender"][0]
    return elem

# %%
def SetDatasetParams(dataset, size):
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(1)
    dataset = dataset.shuffle(size)
    dataset = dataset.repeat()
    return dataset

# %%
def CreateDataset(csvfile, split, label_func):
    
    # Get the size of the dataset
    data = pd.read_csv(csvfile)
    size = data.shape[0]

    # Create a train, validation, test split 
    train_size      = int(split["train"]*size)
    validation_size = int(split["validation"]*size)
    test_size       = int(split["test"]*size)

    full_data       = tf.contrib.data.make_csv_dataset(csvfile, batch_size=1)
    full_data       = full_data.map(label_func, num_parallel_calls=100)
    full_data       = full_data.map(ReadImages, num_parallel_calls=100)

    train_data      = full_data.take(train_size)
    train_data      = SetDatasetParams(train_data, train_size)
    
    validation_data = full_data.skip(train_size)
    test_data       = validation_data.skip(validation_size)
    test_data       = SetDatasetParams(test_data, test_size)
    
    validation_data = validation_data.take(validation_size)
    validation_data = SetDatasetParams(validation_data, validation_size)

    return train_data, validation_data, test_data, size

# %%
train_age, validation_age, test_age, size_age = CreateDataset(AGE_CSV, SPLIT, AgeLabelFunc)
# Out:
# WARNING:tensorflow:From <ipython-input-10-d715e6298c14>:12: make_csv_dataset (from tensorflow.contrib.data.python.ops.readers) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.experimental.make_csv_dataset(...)`.

# %%
train_gen, validation_gen, test_gen, size_gen  = CreateDataset(GEN_CSV, SPLIT, GenderLabelFunc)

# %%
def GetInitOps(train, validation, test):
    init_ops = {}
    it = tf.data.Iterator.from_structure(train.output_types, train.output_shapes)
    init_ops["train"] = it.make_initializer(train)
    init_ops["validation"] = it.make_initializer(validation)
    init_ops["test"] = it.make_initializer(test)
    return init_ops, it

# %%
init_ops_age_data, it_age_data = GetInitOps(train_age, validation_age, test_age)
init_ops_gen_data, it_gen_data = GetInitOps(train_gen, validation_gen, test_gen)

# %%
def GetNumBatchesPerEpoch(size):
    num_batches = {}
    num_batches["train"]      = int((size*SPLIT["train"])//BATCH_SIZE)
    num_batches["validation"] = int((size*SPLIT["validation"])//BATCH_SIZE)
    num_batches["test"]       = int((size*SPLIT["validation"])//BATCH_SIZE)
    return num_batches

# %%
num_batches_age = GetNumBatchesPerEpoch(size_age)
num_batches_gen = GetNumBatchesPerEpoch(size_gen)

# %%
def GetAgeFromBin(bin_val):
    return AGE_MIN + (bin_val*BIN_SIZE)

# %%
def ShowImages(imgs, age, GetLabel):
    high = imgs.eval().shape[0]
    idx = np.random.randint(low=1, high=high, size=2)
    plt.figure(figsize=(8, 8))

    plt.subplot(121)
    curr_img = np.asarray(imgs[idx[0]].eval(), dtype=np.uint8)
    curr_lbl = age[idx[0]].eval()

    plt.imshow(curr_img)
    plt.title("(Label: {lbl})".format(lbl=GetLabel(curr_lbl)))

    plt.subplot(122)
    curr_img = np.asarray(imgs[idx[1]].eval(), dtype=np.uint8)
    curr_lbl = age[idx[1]].eval()
    plt.imshow(curr_img, cmap="gray")
    plt.title("(Label: {lbl})".format(lbl=GetLabel(curr_lbl)))

# %%
def CheckAgeDataset(init_op, it):
    with tf.Session() as sess:
        sess.run(init_op)
        elem = it.get_next()
        ShowImages(elem["name"], elem["age"], GetAgeFromBin)

# %%
#CheckAgeDataset(init_ops_age_data["train"], it_age_data)

# %%
def GetGenFromBin(bin_val):
    if bin_val == 1:
        return "male"
    else:
        return "female"

# %%
def CheckGenDataset(init_op, it):
    with tf.Session() as sess:
        sess.run(init_op)
        elem = it.get_next()
        ShowImages(elem["name"], elem["gender"], GetGenFromBin)

# %%
#CheckGenDataset(init_ops_gen_data["train"], it_gen_data)

# %%
def conv2d(x, W, b, strides=1):
    strides_ = [1, strides, strides, 1]
    x = tf.nn.conv2d(x, W, strides=strides_, padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)

# %%
def maxpool2d(x, k=2):
    ksize_ = [1, k, k, 1]
    strides_ = [1, k, k, 1]
    return tf.nn.max_pool(x, ksize_, strides_, padding='SAME')

# %%
VAL  = IMG_SIZE[0]
FLAT = ceil(ceil(ceil(VAL/2)/2))/2

# %%
weights = {
    'wc1': tf.get_variable('W0', shape=(3, 3, 3, 32), initializer=tf.contrib.layers.xavier_initializer()),
    'wc2': tf.get_variable('W1', shape=(3, 3, 32, 64), initializer=tf.contrib.layers.xavier_initializer()),
    'wc3': tf.get_variable('W2', shape=(3, 3, 64, 128), initializer=tf.contrib.layers.xavier_initializer()),
    'wd1': tf.get_variable('W3', shape=(FLAT*FLAT*128, 128), initializer=tf.contrib.layers.xavier_initializer()),
    'age': tf.get_variable('W4', shape=(128, NUM_CLASSES_AGE), initializer=tf.contrib.layers.xavier_initializer()),
    'gen': tf.get_variable('W5', shape=(128, NUM_CLASSES_GEN), initializer=tf.contrib.layers.xavier_initializer())
}

biases = {
    'bc1': tf.get_variable('B0', shape=(32), initializer=tf.contrib.layers.xavier_initializer()),
    'bc2': tf.get_variable('B1', shape=(64), initializer=tf.contrib.layers.xavier_initializer()),
    'bc3': tf.get_variable('B2', shape=(128), initializer=tf.contrib.layers.xavier_initializer()),
    'bd1': tf.get_variable('B3', shape=(128), initializer=tf.contrib.layers.xavier_initializer()),
    'age': tf.get_variable('B4', shape=(NUM_CLASSES_AGE), initializer=tf.contrib.layers.xavier_initializer()),
    'gen': tf.get_variable('B5', shape=(NUM_CLASSES_GEN), initializer=tf.contrib.layers.xavier_initializer())
}

# %%
# Setup for saving the model with best validation
saver = tf.train.Saver()
save_dir = 'checkpoints-alpha-2-extreme-bias/'

if not os.path.exists(save_dir):
    os.makedirs(save_dir)
    
save_path = os.path.join(save_dir, 'best_validation')

# %%
graph_dir = 'graphs-alpha-2-extreme-bias/'

if os.path.exists(graph_dir):
    shutil.rmtree(graph_dir, ignore_errors=True)

os.makedirs(graph_dir)

# %%
def conv_net(x, weights, biases, task):
    
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    conv1 = maxpool2d(conv1, k=2) 
    
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    conv2 = maxpool2d(conv2, k=2)
    
    conv3 = conv2d(conv2, weights['wc3'], biases['bc3'])
    conv3 = maxpool2d(conv3, k=2)
    
    fc1 = tf.reshape(conv3, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    
    out_gen = tf.add(tf.matmul(fc1, weights['gen']), biases['gen'])
    out_age = tf.add(tf.matmul(fc1, weights['age']), biases['age'])
    
    return out_gen, out_age

# %%
# PRIMARY TASK
# ============

# Running one batch from the age dataset through the network
# Computing the following losses:
# Classification loss (loss_age)
# Confusion loss (loss_confusion)

elem = it_age_data.get_next()
x_age = elem["name"]
y_age = elem["age"]
pred_gen, pred_age = conv_net(x_age, weights, biases, task="primary")

loss_age = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(logits=pred_age, labels=y_age), name="loss_age")

vec = tf.constant([0.5, 0.5])
multiply = tf.shape(x_age)[0]
uniform_gender_lbl = tf.reshape(multiply, [1, ])

gen_labels_op = tf.reshape(tf.tile(vec, uniform_gender_lbl), [ uniform_gender_lbl[0], tf.shape(vec)[0]])

with tf.control_dependencies([gen_labels_op]):
    loss_confusion = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=pred_gen, labels=gen_labels_op), name="loss_confusion")

# Uniform gender labels
# =====================

# We need to compute cross_entropy between 
# uniform_gender distribution and predictions
# uniform_gender = BATCH_SIZE rows of [0.5, 0.5]

optimizer_primary = tf.train.AdamOptimizer(learning_rate=LEARNING_RATE).minimize(loss_age + ALPHA*loss_confusion)

correct_prediction_age = tf.equal(tf.argmax(pred_age, 1), tf.cast(y_age, tf.int64))
accuracy_age = tf.reduce_mean(tf.cast(correct_prediction_age, tf.float32), name="accuracy_age")

# %%
# SECONDARY TASK
# ==============

# Running one batch from the gender dataset through the network
# Computing the following losses:
# Classification loss (loss_gen)

elem = it_gen_data.get_next()
x_gen = elem["name"]
y_gen = elem["gender"]
pred_gen, _ = conv_net(x_gen, weights, biases, task="secondary")
loss_gen = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(logits=pred_gen, labels=y_gen))
optimizer_gen = tf.train.AdamOptimizer(learning_rate=LEARNING_RATE).minimize(loss_gen)

correct_prediction_gen = tf.equal(tf.argmax(pred_gen, 1), tf.cast(y_gen, tf.int64))
accuracy_gen = tf.reduce_mean(tf.cast(correct_prediction_gen, tf.float32))

# %%
# Best validation accuracy seen so far.
best_validation_accuracy_primary   = -1

# Validation accuracy thresholds for
# early stopping training 
age_accuracy_threshold = 0.90
gen_accuracy_threshold = 0.98

# Iteration-number for last improvement to validation accuracy.
last_improvement = 0

# Stop optimization if no improvement found in this many iterations.
require_improvement = 1000

# %%
# TensorFlow Summaries
# Create tf.summary() objects for all the 
# variables we would like to summarize

# Summarising the training losses
loss_age_summary = tf.summary.scalar('loss_age_summary', loss_age)
loss_gen_summary = tf.summary.scalar('loss_gen_summary', loss_gen)
loss_confusion_summary = tf.summary.scalar('loss_confusion_summary', loss_confusion)

# Summarising the training accuracies
acc_age_summary = tf.summary.scalar('acc_age_summary', accuracy_age)
acc_gen_summary = tf.summary.scalar('acc_gen_summary', accuracy_gen)

# Check if the weights are getting updated properly
age_final_layer_summary = tf.summary.histogram('age_final_layer_summary', weights['age'])
gen_final_layer_summary = tf.summary.histogram('gen_final_layer_summary', weights['gen'])

# %%
summaries = [acc_age_summary, loss_age_summary, loss_confusion_summary, age_final_layer_summary, gen_final_layer_summary]
train_primary_summaries = tf.summary.merge(summaries)

summaries = [acc_gen_summary, loss_gen_summary, age_final_layer_summary, gen_final_layer_summary]
train_secondary_summaries = tf.summary.merge(summaries)

# %%
# Global step values for summaries
train_primary_step = 0
train_secondary_step = 0

validation_primary_step = 0
validation_secondary_step = 0

# %%
# Running this op will initialize weights and biases
init_op = tf.global_variables_initializer()

# %%
def SaveModel(sess, acc):
    global best_validation_accuracy_primary
    
    if acc > best_validation_accuracy_primary:
        best_validation_accuracy_primary = acc
        print("[INFO] [PRIMARY] Saving the model parameters")
        saver.save(sess=sess, save_path=save_path)
        return
            
    print("[INFO] [PRIMARY] No improvement in validation accuracy.")

# %%
def ValidateSecondaryTask(sess):
    print("[INFO] [SECONDARY] Running validation for the secondary task.")
    
    global validation_secondary_step
    sess.run(init_ops_gen_data["validation"])
    num_batches = num_batches_gen["validation"]
    
    total_loss = 0
    total_acc  = 0
    for _ in range(num_batches):
        loss, acc = sess.run([loss_gen, accuracy_gen])
        total_loss += loss
        total_acc  += acc

    loss = total_loss/num_batches
    acc = total_acc/num_batches
    
    validation_secondary_step += 1
    summary = tf.Summary()
    summary.value.add(tag='validation_secondary_summary', simple_value = acc)
    writer.add_summary(summary, validation_secondary_step)
    
    print('[INFO] [SECONDARY] Validation Loss: {:.4f}, Accuracy: {:.2f}: '.format(loss, acc))
    
    return acc

# %%
def ValidatePrimaryTask(sess):
    print("[INFO] [PRIMARY] Running validation for the primary task.")
    
    global validation_primary_step
    sess.run(init_ops_age_data["validation"])
    num_batches = num_batches_age["validation"]
    
    total_loss = 0
    total_acc  = 0
    for _ in range(num_batches):
            loss, acc = sess.run([loss_age, accuracy_age])
            total_loss += loss
            total_acc  += acc

    loss = total_loss / num_batches
    acc  = total_acc/ num_batches
    
    validation_primary_step += 1
    summary = tf.Summary()
    summary.value.add(tag='validation_primary_summary', simple_value = acc)
    writer.add_summary(summary, validation_primary_step)
    
    print('[INFO] [PRIMARY] Validation Loss: {:.4f}, Accuracy: {:.2f}: '.format(loss, acc))
    
    SaveModel(sess, acc)
    
    return acc

# %%
def TestPrimaryTask(sess):
    print("\n[INFO] [PRIMARY] Testing on the primary task.")
    
    sess.run(init_ops_age_data["test"])
    num_batches = num_batches_age["test"]

    total_loss = 0
    total_acc  = 0
    for _ in range(num_batches):
        loss, acc = sess.run([loss_age, accuracy_age])
        total_loss += loss
        total_acc  += acc

    loss = total_loss / num_batches
    acc  = total_acc/ num_batches
    print('[INFO] [PRIMARY] Test Loss: {:.4f}, Accuracy: {:.2f}: '.format(loss, acc))

# %%
def TestSecondaryTask(sess):
    print("\n[INFO] [SECONDARY] Testing the secondary task.")

    sess.run(init_ops_gen_data["test"])
    num_batches = num_batches_gen["test"]
    
    total_loss = 0
    total_acc  = 0
    for _ in range(num_batches):
        loss, acc = sess.run([loss_gen, accuracy_gen])
        total_loss += loss
        total_acc  += acc

    loss = total_loss/num_batches
    acc  = total_acc/num_batches
    print('[INFO] [SECONDARY] Test Loss: {:.4f}, Accuracy: {:.2f}: '.format(loss, acc))

# %%
def TrainPrimaryTask(sess, iter_num):
    print("\n[INFO] [PRIMARY] Training for the primary task.")
    
    global train_primary_step
    sess.run(init_ops_age_data["train"])
    num_batches = num_batches_age["train"]
    
    for epoch in range(EPOCHS):
    
        total_loss = 0
        for i in range(num_batches):
            var = [loss_age, loss_confusion, accuracy_age, optimizer_primary]
            loss, conf, acc, _ = sess.run(var)
            total_loss += loss

        avg_loss = total_loss / num_batches

        train_primary_step += 1
        summary = sess.run(train_primary_summaries)
        writer.add_summary(summary, train_primary_step)

        print("[INFO] [PRIMARY] Iter: {}, Epoch: {}, Loss: {:.4f}, Accuracy: {:.2f}".format(iter_num, epoch,  avg_loss, acc))
    
        acc = ValidatePrimaryTask(sess)
        if acc > age_accuracy_threshold:
            print("[INFO] [PRIMARY] Fully optimized, stopping early.")
            break

# %%
def TrainSecondaryTask(sess, iter_num):
    print("\n[INFO] [SECONDARY] Training for the secondary task.")
    
    global train_secondary_step
    sess.run(init_ops_gen_data["train"])
    num_batches = num_batches_gen["train"]
    
    for i in range(EPOCHS):
        
        total_loss = 0
        for _ in range(num_batches):
            var = [optimizer_gen, loss_gen, accuracy_gen]
            _, loss, acc = sess.run(var)
            total_loss += loss
        
        avg_loss = total_loss / num_batches
        
        train_secondary_step += 1
        summary = sess.run(train_secondary_summaries)
        writer.add_summary(summary, train_secondary_step)
        
        print("[INFO] [SECONDARY] Iter: {}, Epoch: {}, Loss: {:.4f}, Accuracy: {:.2f}".format(iter_num, i,  avg_loss, acc))
            
        acc = ValidateSecondaryTask(sess)
        if acc > gen_accuracy_threshold:
            print("[INFO] [SECONDARY] Fully optimized, stopping early.")
            break

# %%
def JLU(sess):
    print("[INFO] JLU training for gender agnostic age prediction.")
    sess.run(init_op)

    for iter_num in range(ITERS):
        TrainSecondaryTask(sess, iter_num)
        TrainPrimaryTask(sess, iter_num)

    # Restore the best validation weights before testing
    saver.restore(sess=sess, save_path=save_path)
    
    # This would hopefully be bad
    TestSecondaryTask(sess)
    
    # This would hopefully be good
    TestPrimaryTask(sess)

# %%
t1 = time()

with tf.Session() as sess:
    writer = tf.summary.FileWriter(graph_dir, sess.graph)
    JLU(sess)

t2 = time()
print("[INFO] JLU training for gender agnostic age prediction took {:.2f} minutes".format((t2-t1)/60))
# Out:
# [INFO] JLU training for gender agnostic age prediction.
#
# [INFO] [SECONDARY] Training for the secondary task.
# [INFO] [SECONDARY] Iter: 0, Epoch: 0, Loss: 25.1462, Accuracy: 0.91
# [INFO] [SECONDARY] Running validation for the secondary task.
# [INFO] [SECONDARY] Validation Loss: 0.4388, Accuracy: 0.80:
# [INFO] [SECONDARY] Iter: 0, Epoch: 1, Loss: 0.1697, Accuracy: 1.00
# [INFO] [SECONDARY] Running validation for the secondary task.
# [INFO] [SECONDARY] Validation Loss: 0.1198, Accuracy: 0.96:
# [INFO] [SECONDARY] Iter: 0, Epoch: 2, Loss: 0.0433, Accuracy: 1.00
# [INFO] [SECONDARY] Running validation for the secondary task.
# [INFO] [SECONDARY] Validation Loss: 0.0401, Accuracy: 0.99:
# [INFO] [SECONDARY] Fully optimized, stopping early.
#
# [INFO] [PRIMARY] Training for the primary task.
# [INFO] [PRIMARY] Iter: 0, Epoch: 0, Loss: 2.6369, Accuracy: 0.22
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 2.4032, Accuracy: 0.16:
# [INFO] [PRIMARY] Saving the model parameters
# [INFO] [PRIMARY] Iter: 0, Epoch: 1, Loss: 2.1248, Accuracy: 0.50
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 2.0673, Accuracy: 0.25:
# [INFO] [PRIMARY] Saving the model parameters
# [INFO] [PRIMARY] Iter: 0, Epoch: 2, Loss: 1.4817, Accuracy: 0.78
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 2.4991, Accuracy: 0.22:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 0, Epoch: 3, Loss: 1.5543, Accuracy: 0.81
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 2.1686, Accuracy: 0.34:
# [INFO] [PRIMARY] Saving the model parameters
# [INFO] [PRIMARY] Iter: 0, Epoch: 4, Loss: 1.3680, Accuracy: 0.81
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 1.6695, Accuracy: 0.44:
# [INFO] [PRIMARY] Saving the model parameters
# [INFO] [PRIMARY] Iter: 0, Epoch: 5, Loss: 1.0077, Accuracy: 0.84
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 2.8787, Accuracy: 0.36:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 0, Epoch: 6, Loss: 1.3296, Accuracy: 0.91
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 2.4261, Accuracy: 0.32:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 0, Epoch: 7, Loss: 1.0045, Accuracy: 0.94
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 2.8641, Accuracy: 0.39:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 0, Epoch: 8, Loss: 1.0556, Accuracy: 0.97
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 2.2251, Accuracy: 0.43:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 0, Epoch: 9, Loss: 0.9515, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 3.1252, Accuracy: 0.45:
# [INFO] [PRIMARY] Saving the model parameters
# [INFO] [PRIMARY] Iter: 0, Epoch: 10, Loss: 1.0314, Accuracy: 0.91
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 2.2438, Accuracy: 0.36:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 0, Epoch: 11, Loss: 0.9768, Accuracy: 0.97
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 2.5180, Accuracy: 0.37:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 0, Epoch: 12, Loss: 1.0000, Accuracy: 0.91
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 1.7893, Accuracy: 0.55:
# [INFO] [PRIMARY] Saving the model parameters
# [INFO] [PRIMARY] Iter: 0, Epoch: 13, Loss: 0.7490, Accuracy: 0.94
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 2.6993, Accuracy: 0.46:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 0, Epoch: 14, Loss: 1.0835, Accuracy: 0.97
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 2.1492, Accuracy: 0.48:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 0, Epoch: 15, Loss: 0.8090, Accuracy: 0.91
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 2.3510, Accuracy: 0.49:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 0, Epoch: 16, Loss: 0.7405, Accuracy: 0.97
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 1.6035, Accuracy: 0.52:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 0, Epoch: 17, Loss: 0.5973, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 2.2690, Accuracy: 0.51:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 0, Epoch: 18, Loss: 0.7310, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 2.4100, Accuracy: 0.47:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 0, Epoch: 19, Loss: 0.7071, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 1.9159, Accuracy: 0.51:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 0, Epoch: 20, Loss: 0.8023, Accuracy: 0.91
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 1.5885, Accuracy: 0.54:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 0, Epoch: 21, Loss: 0.5598, Accuracy: 0.97
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 1.8913, Accuracy: 0.57:
# [INFO] [PRIMARY] Saving the model parameters
# [INFO] [PRIMARY] Iter: 0, Epoch: 22, Loss: 0.6706, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 1.3745, Accuracy: 0.65:
# [INFO] [PRIMARY] Saving the model parameters
# [INFO] [PRIMARY] Iter: 0, Epoch: 23, Loss: 0.3968, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 1.7495, Accuracy: 0.52:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 0, Epoch: 24, Loss: 0.5183, Accuracy: 0.94
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 1.2099, Accuracy: 0.68:
# [INFO] [PRIMARY] Saving the model parameters
# [INFO] [PRIMARY] Iter: 0, Epoch: 25, Loss: 0.3781, Accuracy: 0.97
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 1.5160, Accuracy: 0.64:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 0, Epoch: 26, Loss: 0.4938, Accuracy: 0.94
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 1.3891, Accuracy: 0.68:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 0, Epoch: 27, Loss: 0.3682, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 1.2841, Accuracy: 0.71:
# [INFO] [PRIMARY] Saving the model parameters
# [INFO] [PRIMARY] Iter: 0, Epoch: 28, Loss: 0.3424, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 1.3373, Accuracy: 0.62:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 0, Epoch: 29, Loss: 0.4066, Accuracy: 0.97
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 1.3235, Accuracy: 0.71:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 0, Epoch: 30, Loss: 0.3105, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 1.5160, Accuracy: 0.71:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 0, Epoch: 31, Loss: 0.3369, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.8250, Accuracy: 0.80:
# [INFO] [PRIMARY] Saving the model parameters
# [INFO] [PRIMARY] Iter: 0, Epoch: 32, Loss: 0.2372, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.7904, Accuracy: 0.76:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 0, Epoch: 33, Loss: 0.2306, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 1.0811, Accuracy: 0.78:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 0, Epoch: 34, Loss: 0.3465, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 1.0943, Accuracy: 0.72:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 0, Epoch: 35, Loss: 0.3114, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.7776, Accuracy: 0.77:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 0, Epoch: 36, Loss: 0.1960, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 1.4125, Accuracy: 0.76:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 0, Epoch: 37, Loss: 0.3475, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.8429, Accuracy: 0.76:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 0, Epoch: 38, Loss: 0.2304, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.8074, Accuracy: 0.78:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 0, Epoch: 39, Loss: 0.2140, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.7886, Accuracy: 0.79:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 0, Epoch: 40, Loss: 0.2158, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.5883, Accuracy: 0.84:
# [INFO] [PRIMARY] Saving the model parameters
# [INFO] [PRIMARY] Iter: 0, Epoch: 41, Loss: 0.1310, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 1.2478, Accuracy: 0.77:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 0, Epoch: 42, Loss: 0.2839, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.8040, Accuracy: 0.81:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 0, Epoch: 43, Loss: 0.1695, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.6791, Accuracy: 0.84:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 0, Epoch: 44, Loss: 0.2123, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.6062, Accuracy: 0.83:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 0, Epoch: 45, Loss: 0.1358, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.5289, Accuracy: 0.85:
# [INFO] [PRIMARY] Saving the model parameters
# [INFO] [PRIMARY] Iter: 0, Epoch: 46, Loss: 0.1517, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.5390, Accuracy: 0.83:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 0, Epoch: 47, Loss: 0.1285, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.2942, Accuracy: 0.87:
# [INFO] [PRIMARY] Saving the model parameters
# [INFO] [PRIMARY] Iter: 0, Epoch: 48, Loss: 0.0727, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.7420, Accuracy: 0.86:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 0, Epoch: 49, Loss: 0.1825, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.7601, Accuracy: 0.80:
# [INFO] [PRIMARY] No improvement in validation accuracy.
#
# [INFO] [SECONDARY] Training for the secondary task.
# [INFO] [SECONDARY] Iter: 1, Epoch: 0, Loss: 0.2460, Accuracy: 1.00
# [INFO] [SECONDARY] Running validation for the secondary task.
# [INFO] [SECONDARY] Validation Loss: 0.0326, Accuracy: 0.99:
# [INFO] [SECONDARY] Fully optimized, stopping early.
#
# [INFO] [PRIMARY] Training for the primary task.
# [INFO] [PRIMARY] Iter: 1, Epoch: 0, Loss: 1.3351, Accuracy: 0.66
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.7685, Accuracy: 0.80:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 1, Epoch: 1, Loss: 0.3382, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.6171, Accuracy: 0.78:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 1, Epoch: 2, Loss: 0.1923, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.8052, Accuracy: 0.70:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 1, Epoch: 3, Loss: 0.2532, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 1.1960, Accuracy: 0.76:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 1, Epoch: 4, Loss: 0.2311, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.7186, Accuracy: 0.77:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 1, Epoch: 5, Loss: 0.1674, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.8730, Accuracy: 0.80:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 1, Epoch: 6, Loss: 0.2310, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.9286, Accuracy: 0.79:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 1, Epoch: 7, Loss: 0.2458, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.9584, Accuracy: 0.71:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 1, Epoch: 8, Loss: 0.2675, Accuracy: 0.97
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.8939, Accuracy: 0.78:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 1, Epoch: 9, Loss: 0.2573, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.5934, Accuracy: 0.83:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 1, Epoch: 10, Loss: 0.1530, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.4947, Accuracy: 0.81:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 1, Epoch: 11, Loss: 0.1768, Accuracy: 0.97
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.5720, Accuracy: 0.84:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 1, Epoch: 12, Loss: 0.1242, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.4234, Accuracy: 0.87:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 1, Epoch: 13, Loss: 0.1125, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.5175, Accuracy: 0.85:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 1, Epoch: 14, Loss: 0.1207, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.6102, Accuracy: 0.90:
# [INFO] [PRIMARY] Saving the model parameters
# [INFO] [PRIMARY] Iter: 1, Epoch: 15, Loss: 0.1394, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.6500, Accuracy: 0.81:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 1, Epoch: 16, Loss: 0.1350, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.2892, Accuracy: 0.91:
# [INFO] [PRIMARY] Saving the model parameters
# [INFO] [PRIMARY] Fully optimized, stopping early.
#
# [INFO] [SECONDARY] Training for the secondary task.
# [INFO] [SECONDARY] Iter: 2, Epoch: 0, Loss: 0.2228, Accuracy: 1.00
# [INFO] [SECONDARY] Running validation for the secondary task.
# [INFO] [SECONDARY] Validation Loss: 0.0115, Accuracy: 1.00:
# [INFO] [SECONDARY] Fully optimized, stopping early.
#
# [INFO] [PRIMARY] Training for the primary task.
# [INFO] [PRIMARY] Iter: 2, Epoch: 0, Loss: 1.3312, Accuracy: 0.75
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.7255, Accuracy: 0.76:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 2, Epoch: 1, Loss: 0.2655, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.5980, Accuracy: 0.80:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 2, Epoch: 2, Loss: 0.1783, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.9274, Accuracy: 0.73:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 2, Epoch: 3, Loss: 0.2232, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.6100, Accuracy: 0.80:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 2, Epoch: 4, Loss: 0.1652, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.8499, Accuracy: 0.78:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 2, Epoch: 5, Loss: 0.1971, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 1.3854, Accuracy: 0.67:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 2, Epoch: 6, Loss: 0.1827, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.5636, Accuracy: 0.89:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 2, Epoch: 7, Loss: 0.1212, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.7857, Accuracy: 0.80:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 2, Epoch: 8, Loss: 0.1567, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.5285, Accuracy: 0.85:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 2, Epoch: 9, Loss: 0.1101, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.5516, Accuracy: 0.86:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 2, Epoch: 10, Loss: 0.1397, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.2587, Accuracy: 0.91:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Fully optimized, stopping early.
#
# [INFO] [SECONDARY] Training for the secondary task.
# [INFO] [SECONDARY] Iter: 3, Epoch: 0, Loss: 0.2151, Accuracy: 1.00
# [INFO] [SECONDARY] Running validation for the secondary task.
# [INFO] [SECONDARY] Validation Loss: 0.0068, Accuracy: 1.00:
# [INFO] [SECONDARY] Fully optimized, stopping early.
#
# [INFO] [PRIMARY] Training for the primary task.
# [INFO] [PRIMARY] Iter: 3, Epoch: 0, Loss: 1.1853, Accuracy: 0.72
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.6933, Accuracy: 0.81:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 3, Epoch: 1, Loss: 0.1895, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.6508, Accuracy: 0.83:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 3, Epoch: 2, Loss: 0.1618, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.5230, Accuracy: 0.79:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 3, Epoch: 3, Loss: 0.1066, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.7468, Accuracy: 0.83:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 3, Epoch: 4, Loss: 0.1561, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.5686, Accuracy: 0.84:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 3, Epoch: 5, Loss: 0.0931, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.5318, Accuracy: 0.89:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 3, Epoch: 6, Loss: 0.0961, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.5690, Accuracy: 0.85:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 3, Epoch: 7, Loss: 0.1487, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.3580, Accuracy: 0.88:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 3, Epoch: 8, Loss: 0.0665, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.1891, Accuracy: 0.92:
# [INFO] [PRIMARY] Saving the model parameters
# [INFO] [PRIMARY] Fully optimized, stopping early.
#
# [INFO] [SECONDARY] Training for the secondary task.
# [INFO] [SECONDARY] Iter: 4, Epoch: 0, Loss: 0.2219, Accuracy: 1.00
# [INFO] [SECONDARY] Running validation for the secondary task.
# [INFO] [SECONDARY] Validation Loss: 0.0117, Accuracy: 1.00:
# [INFO] [SECONDARY] Fully optimized, stopping early.
#
# [INFO] [PRIMARY] Training for the primary task.
# [INFO] [PRIMARY] Iter: 4, Epoch: 0, Loss: 0.9185, Accuracy: 0.84
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.6120, Accuracy: 0.85:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 4, Epoch: 1, Loss: 0.1718, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.2549, Accuracy: 0.90:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Fully optimized, stopping early.
#
# [INFO] [SECONDARY] Training for the secondary task.
# [INFO] [SECONDARY] Iter: 5, Epoch: 0, Loss: 0.2589, Accuracy: 0.97
# [INFO] [SECONDARY] Running validation for the secondary task.
# [INFO] [SECONDARY] Validation Loss: 0.0297, Accuracy: 0.98:
# [INFO] [SECONDARY] Fully optimized, stopping early.
#
# [INFO] [PRIMARY] Training for the primary task.
# [INFO] [PRIMARY] Iter: 5, Epoch: 0, Loss: 1.1915, Accuracy: 0.78
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.7879, Accuracy: 0.74:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 5, Epoch: 1, Loss: 0.1660, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.4123, Accuracy: 0.87:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 5, Epoch: 2, Loss: 0.0814, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.6259, Accuracy: 0.76:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 5, Epoch: 3, Loss: 0.1437, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.2019, Accuracy: 0.95:
# [INFO] [PRIMARY] Saving the model parameters
# [INFO] [PRIMARY] Fully optimized, stopping early.
#
# [INFO] [SECONDARY] Training for the secondary task.
# [INFO] [SECONDARY] Iter: 6, Epoch: 0, Loss: 0.2342, Accuracy: 1.00
# [INFO] [SECONDARY] Running validation for the secondary task.
# [INFO] [SECONDARY] Validation Loss: 0.0067, Accuracy: 1.00:
# [INFO] [SECONDARY] Fully optimized, stopping early.
#
# [INFO] [PRIMARY] Training for the primary task.
# [INFO] [PRIMARY] Iter: 6, Epoch: 0, Loss: 1.6215, Accuracy: 0.78
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.8333, Accuracy: 0.72:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 6, Epoch: 1, Loss: 0.2555, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.6072, Accuracy: 0.84:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 6, Epoch: 2, Loss: 0.1332, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.7363, Accuracy: 0.84:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 6, Epoch: 3, Loss: 0.1364, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.5194, Accuracy: 0.82:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 6, Epoch: 4, Loss: 0.1263, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.5561, Accuracy: 0.82:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 6, Epoch: 5, Loss: 0.1155, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.4365, Accuracy: 0.88:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 6, Epoch: 6, Loss: 0.1617, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.7950, Accuracy: 0.78:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 6, Epoch: 7, Loss: 0.1628, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.5946, Accuracy: 0.82:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 6, Epoch: 8, Loss: 0.1011, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.3637, Accuracy: 0.89:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 6, Epoch: 9, Loss: 0.0724, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.5105, Accuracy: 0.86:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 6, Epoch: 10, Loss: 0.1427, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.5316, Accuracy: 0.88:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 6, Epoch: 11, Loss: 0.1036, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.3385, Accuracy: 0.89:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 6, Epoch: 12, Loss: 0.0728, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.4793, Accuracy: 0.87:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 6, Epoch: 13, Loss: 0.0778, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.3196, Accuracy: 0.90:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Fully optimized, stopping early.
#
# [INFO] [SECONDARY] Training for the secondary task.
# [INFO] [SECONDARY] Iter: 7, Epoch: 0, Loss: 0.2449, Accuracy: 1.00
# [INFO] [SECONDARY] Running validation for the secondary task.
# [INFO] [SECONDARY] Validation Loss: 0.0412, Accuracy: 0.99:
# [INFO] [SECONDARY] Fully optimized, stopping early.
#
# [INFO] [PRIMARY] Training for the primary task.
# [INFO] [PRIMARY] Iter: 7, Epoch: 0, Loss: 0.9017, Accuracy: 0.69
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.5373, Accuracy: 0.84:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 7, Epoch: 1, Loss: 0.1674, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.2993, Accuracy: 0.91:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Fully optimized, stopping early.
#
# [INFO] [SECONDARY] Training for the secondary task.
# [INFO] [SECONDARY] Iter: 8, Epoch: 0, Loss: 0.3578, Accuracy: 1.00
# [INFO] [SECONDARY] Running validation for the secondary task.
# [INFO] [SECONDARY] Validation Loss: 0.0375, Accuracy: 0.99:
# [INFO] [SECONDARY] Fully optimized, stopping early.
#
# [INFO] [PRIMARY] Training for the primary task.
# [INFO] [PRIMARY] Iter: 8, Epoch: 0, Loss: 1.1215, Accuracy: 0.94
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.4367, Accuracy: 0.87:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 8, Epoch: 1, Loss: 0.1146, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.3293, Accuracy: 0.88:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 8, Epoch: 2, Loss: 0.0807, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.2302, Accuracy: 0.96:
# [INFO] [PRIMARY] Saving the model parameters
# [INFO] [PRIMARY] Fully optimized, stopping early.
#
# [INFO] [SECONDARY] Training for the secondary task.
# [INFO] [SECONDARY] Iter: 9, Epoch: 0, Loss: 0.2809, Accuracy: 1.00
# [INFO] [SECONDARY] Running validation for the secondary task.
# [INFO] [SECONDARY] Validation Loss: 0.0451, Accuracy: 0.98:
# [INFO] [SECONDARY] Fully optimized, stopping early.
#
# [INFO] [PRIMARY] Training for the primary task.
# [INFO] [PRIMARY] Iter: 9, Epoch: 0, Loss: 0.7699, Accuracy: 0.94
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.4276, Accuracy: 0.85:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Iter: 9, Epoch: 1, Loss: 0.1582, Accuracy: 1.00
# [INFO] [PRIMARY] Running validation for the primary task.
# [INFO] [PRIMARY] Validation Loss: 0.1787, Accuracy: 0.94:
# [INFO] [PRIMARY] No improvement in validation accuracy.
# [INFO] [PRIMARY] Fully optimized, stopping early.
# INFO:tensorflow:Restoring parameters from checkpoints-alpha-2-extreme-bias/best_validation
#
# [INFO] [SECONDARY] Testing the secondary task.
# [INFO] [SECONDARY] Test Loss: 0.6945, Accuracy: 0.48:
#
# [INFO] [PRIMARY] Testing on the primary task.
# [INFO] [PRIMARY] Test Loss: 0.3197, Accuracy: 0.91:
# [INFO] JLU training for gender agnostic age prediction took 9.77 minutes
